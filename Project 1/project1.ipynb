# %% [markdown]
# # CS672 Deep Learning Project #1
#
# Aayushi Verma

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import tensorflow as tf

# %% [markdown]
# ## Dataset
#
# We are using the Wine dataset (https://archive.ics.uci.edu/dataset/109/wine) donated to UCI Machine Learning Repository. We will explore the characteristics of the dataset through exploratory data analysis and will create a deep learning model to train the dataset.

# %%
wine_names = ['Class', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash', 'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols', 'Proanthocyanins', 'Color intensity', 'Hue', 'OD280/OD315', 'Proline']
df = pd.read_csv('wine/wine.data', names = wine_names) 
df.head()
# Out:
#    Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  OD280/OD315  Proline
# 0             5.64  1.04         3.92     1065
# 1             4.38  1.05         3.40     1050
# 2             5.68  1.03         3.17     1185
# 3             7.80  0.86         3.45     1480
# 4             4.32  1.04         2.93      735

# %%
df.shape
# Out:
# (178, 14)

# %%
df.describe()
# Out:
#             Class     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# min     70.000000       0.980000    0.340000              0.130000
# 25%     88.000000       1.742500    1.205000              0.270000
# 50%     98.000000       2.355000    2.135000              0.340000
# 75%    107.000000       2.800000    2.875000              0.437500
# max    162.000000       3.880000    5.080000              0.660000
#
#        Proanthocyanins  Color intensity         Hue  OD280/OD315      Proline
# count       178.000000       178.000000  178.000000   178.000000   178.000000
# mean          1.590899         5.058090    0.957449     2.611685   746.893258
# std           0.572359         2.318286    0.228572     0.709990   314.907474
# min           0.410000         1.280000    0.480000     1.270000   278.000000
# 25%           1.250000         3.220000    0.782500     1.937500   500.500000
# 50%           1.555000         4.690000    0.965000     2.780000   673.500000
# 75%           1.950000         6.200000    1.120000     3.170000   985.000000
# max           3.580000        13.000000    1.710000     4.000000  1680.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Class                 178 non-null    int64
#  1   Alcohol               178 non-null    float64
#  2   Malic acid            178 non-null    float64
#  3   Ash                   178 non-null    float64
#  4   Alcalinity of ash     178 non-null    float64
#  5   Magnesium             178 non-null    int64
#  6   Total phenols         178 non-null    float64
#  7   Flavanoids            178 non-null    float64
#  8   Nonflavanoid phenols  178 non-null    float64
#  9   Proanthocyanins       178 non-null    float64
#  10  Color intensity       178 non-null    float64
#  11  Hue                   178 non-null    float64
#  12  OD280/OD315           178 non-null    float64
#  13  Proline               178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %% [markdown]
# Prep the data in order to be ready to be fed to a model.
# Look for missing, null, NaN records.
# Find outliers.
# Transform data – all entries should be numeric.

# %%
df.isnull().sum()
# Out:
# Class                   0
# Alcohol                 0
# Malic acid              0
# Ash                     0
# Alcalinity of ash       0
# Magnesium               0
# Total phenols           0
# Flavanoids              0
# Nonflavanoid phenols    0
# Proanthocyanins         0
# Color intensity         0
# Hue                     0
# OD280/OD315             0
# Proline                 0
# dtype: int64

# %%
# finding columns in the df which have any null/na values
np.where(pd.isna(df))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
corr = df.corr()
corr.style.background_gradient('coolwarm')
# Out:
# <style type="text/css">
# #T_8af80_row0_col0, #T_8af80_row1_col1, #T_8af80_row2_col2, #T_8af80_row3_col3, #T_8af80_row4_col4, #T_8af80_row5_col5, #T_8af80_row6_col6, #T_8af80_row7_col7, #T_8af80_row8_col8, #T_8af80_row9_col9, #T_8af80_row10_col10, #T_8af80_row11_col11, #T_8af80_row12_col12, #T_8af80_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8af80_row0_col1, #T_8af80_row0_col6, #T_8af80_row0_col7, #T_8af80_row0_col9, #T_8af80_row0_col11, #T_8af80_row0_col12, #T_8af80_row0_col13, #T_8af80_row7_col0, #T_8af80_row7_col8, #T_8af80_row8_col5, #T_8af80_row11_col2, #T_8af80_row11_col3, #T_8af80_row11_col10, #T_8af80_row13_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8af80_row0_col2 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_8af80_row0_col3, #T_8af80_row12_col8 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_8af80_row0_col4, #T_8af80_row0_col8 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_8af80_row0_col5 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_8af80_row0_col10, #T_8af80_row10_col2, #T_8af80_row13_col5 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_8af80_row1_col0, #T_8af80_row13_col3 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_8af80_row1_col2, #T_8af80_row1_col5 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_8af80_row1_col3, #T_8af80_row4_col7 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_8af80_row1_col4 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_8af80_row1_col6, #T_8af80_row1_col7 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_8af80_row1_col8, #T_8af80_row5_col4, #T_8af80_row11_col5 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_8af80_row1_col9, #T_8af80_row7_col1 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_8af80_row1_col10 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_8af80_row1_col11, #T_8af80_row3_col9, #T_8af80_row5_col3 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_8af80_row1_col12, #T_8af80_row4_col3 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_8af80_row1_col13 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_8af80_row2_col0 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_8af80_row2_col1, #T_8af80_row10_col4 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_8af80_row2_col3, #T_8af80_row8_col11 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_8af80_row2_col4, #T_8af80_row2_col10 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_8af80_row2_col5 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_8af80_row2_col6 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_8af80_row2_col7, #T_8af80_row2_col12, #T_8af80_row13_col2 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_8af80_row2_col8 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_8af80_row2_col9 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_8af80_row2_col11, #T_8af80_row12_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_8af80_row2_col13 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_8af80_row3_col0, #T_8af80_row3_col5 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_8af80_row3_col1 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_8af80_row3_col2, #T_8af80_row6_col1 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_8af80_row3_col4, #T_8af80_row13_col12 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_8af80_row3_col6 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_8af80_row3_col7 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_8af80_row3_col8 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_8af80_row3_col10 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_8af80_row3_col11 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_8af80_row3_col12 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_8af80_row3_col13 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_8af80_row4_col0, #T_8af80_row6_col9 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_8af80_row4_col1 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_8af80_row4_col2, #T_8af80_row5_col6 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_8af80_row4_col5 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_8af80_row4_col6 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_8af80_row4_col8 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_8af80_row4_col9, #T_8af80_row10_col12 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_8af80_row4_col10 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_8af80_row4_col11 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_8af80_row4_col12 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_8af80_row4_col13 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_8af80_row5_col0 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_8af80_row5_col1 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_8af80_row5_col2, #T_8af80_row9_col10 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_8af80_row5_col7, #T_8af80_row9_col11 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_8af80_row5_col8 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_8af80_row5_col9 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_8af80_row5_col10 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_8af80_row5_col11 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_8af80_row5_col12 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_8af80_row5_col13 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_8af80_row6_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_8af80_row6_col2, #T_8af80_row13_col8 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_8af80_row6_col3, #T_8af80_row9_col0 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_8af80_row6_col4 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_8af80_row6_col5 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_8af80_row6_col7 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_8af80_row6_col8 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_8af80_row6_col10 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_8af80_row6_col11 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_8af80_row6_col12 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_8af80_row6_col13 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_8af80_row7_col2 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_8af80_row7_col3, #T_8af80_row11_col8 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_8af80_row7_col4, #T_8af80_row10_col11, #T_8af80_row12_col10 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_8af80_row7_col5, #T_8af80_row10_col5 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_8af80_row7_col6 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_8af80_row7_col9 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_8af80_row7_col10 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_8af80_row7_col11 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_8af80_row7_col12 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_8af80_row7_col13 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_8af80_row8_col0, #T_8af80_row13_col7 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_8af80_row8_col1 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_8af80_row8_col2, #T_8af80_row13_col10 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_8af80_row8_col3 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_8af80_row8_col4 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_8af80_row8_col6, #T_8af80_row8_col12 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_8af80_row8_col7 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_8af80_row8_col9 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_8af80_row8_col10 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_8af80_row8_col13 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_8af80_row9_col1 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_8af80_row9_col2 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_8af80_row9_col3 {
#   background-color: #536edd;
#   color: #f1f

# %%
# plotting correlation of variables against each other
# sns.pairplot(corr)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/av15397n/Documents/GitHub/CS672-Deep-Learning/Project 1/project1.ipynb Cell 12 line 2
#       <a href='vscode-notebook-cell:/Users/av15397n/Documents/GitHub/CS672-Deep-Learning/Project%201/project1.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> # plotting correlation of variables against each other
# ----> <a href='vscode-notebook-cell:/Users/av15397n/Documents/GitHub/CS672-Deep-Learning/Project%201/project1.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> sns.pairplot(corr)
#
# File ~/Documents/GitHub/.venv/lib/python3.11/site-packages/seaborn/axisgrid.py:2174, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2171 if hue is not None:
#    2172     grid.add_legend()
# -> 2174 grid.tight_layout()
#    2176 return grid
#
# File ~/Documents/GitHub/.venv/lib/python3.11/site-packages/seaborn/axisgrid.py:118, in Grid.tight_layout(self, *args, **kwargs)
#     116 if self._tight_layout_pad is not None:
#     117     kwargs.setdefault("pad", self._tight_layout_pad)
# --> 118 self._figure.tight_layout(*args, **kwargs)
#     119 return self
#
# File ~/Documents/GitHub/.venv/lib/python3.11/site-packages/matplotlib/figure.py:3544, in Figure.tight_layout(self, pad, h_pad, w_pad, rect)
#    3542 previous_engine = self.get_layout_engine()
#    3543 self.set_layout_engine(engine)
# -> 3544 engine.execute(self)
#    3545 if not isinstance(previous_engine, TightLayoutEngine) \
#    3546         and previous_engine is not None:
#    3547     _api.warn_external('The figure layout has changed to tight')
#
# File ~/Documents/GitHub/.venv/lib/python3.11/site-packages/matplotlib/layout_engine.py:184, in TightLayoutEngine.execute(self, fig)
#     182 renderer = fig._get_renderer()
#     183 with getattr(renderer, "_draw_disabled", nullcontext)():
# --> 184     kwargs = get_tight_layout_figure(
#     185         fig, fig.axes, get_subplotspec_list(fig.axes), renderer,
#     186         pad=info['pad'], h_pad=info['h_pad'], w_pad=info['w_pad'],
#     187         rect=info['rect'])
#     188 if kwargs:
#     189     fig.subplots_adjust(**kwargs)
#
# File ~/Documents/GitHub/.venv/lib/python3.11/site-packages/matplotlib/_tight_layout.py:266, in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     261         return {}
#     262     span_pairs.append((
#     263         slice(ss.rowspan.start * div_row, ss.rowspan.stop * div_row),
#     264         slice(ss.colspan.start * div_col, ss.colspan.stop * div_col)))
# --> 266 kwargs = _auto_adjust_subplotpars(fig, renderer,
#     267                                   shape=(max_nrows, max_ncols),
#     268                                   span_pairs=span_pairs,
#     269                                   subplot_list=subplot_list,
#     270                                   ax_bbox_list=ax_bbox_list,
#     271                                   pad=pad, h_pad=h_pad, w_pad=w_pad)
#     273 # kwargs can be none if tight_layout fails...
#     274 if rect is not None and kwargs is not None:
#     275     # if rect is given, the whole subplots area (including
#     276     # labels) will fit into the rect instead of the
#    (...)
#     280     # auto_adjust_subplotpars twice, where the second run
#     281     # with adjusted rect parameters.
#
# File ~/Documents/GitHub/.venv/lib/python3.11/site-packages/matplotlib/_tight_layout.py:82, in _auto_adjust_subplotpars(fig, renderer, shape, span_pairs, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#      80 for ax in subplots:
#      81     if ax.get_visible():
# ---> 82         bb += [martist._get_tightbbox_for_layout_only(ax, renderer)]
#      84 tight_bbox_raw = Bbox.union(bb)
#      85 tight_bbox = fig.transFigure.inverted().transform_bbox(tight_bbox_raw)
#
# File ~/Documents/GitHub/.venv/lib/python3.11/site-packages/matplotlib/artist.py:1415, in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1409 """
#    1410 Matplotlib's `.Axes.get_tightbbox` and `.Axis.get_tightbbox` support a
#    1411 *for_layout_only* kwarg; this helper tries to use the kwarg but skips it
#    1412 when encountering third-party subclasses that do not support it.
#    1413 """
#    1414 try:
# -> 1415     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1416 except TypeError:
#    1417     return obj.get_tightbbox(*args, **kwargs)
#
# File ~/Documents/GitHub/.venv/lib/python3.11/site-packages/matplotlib/axes/_base.py:4388, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4386         if ba:
#    4387             bb.append(ba)
# -> 4388 self._update_title_position(renderer)
#    4389 axbbox = self.get_window_extent(renderer)
#    4390 bb.append(axbbox)
#
# File ~/Documents/GitHub/.venv/lib/python3.11/site-packages/matplotlib/axes/_base.py:2963, in _AxesBase._update_title_position(self, renderer)
#    2960 bb = None
#    2961 if (ax.xaxis.get_ticks_position() in ['top', 'unknown']
#    2962         or ax.xaxis.get_label_position() == 'top'):
# -> 2963     bb = ax.xaxis.get_tightbbox(renderer)
#    2964 if bb is None:
#    2965     if 'outline' in ax.spines:
#    2966         # Special case for colorbars:
#
# File ~/Documents/GitHub/.venv/lib/python3.11/site-packages/matplotlib/axis.py:1323, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1321 if renderer is None:
#    1322     renderer = self.figure._get_renderer()
# -> 1323 ticks_to_draw = self._update_ticks()
#    1325 self._update_label_position(renderer)
#    1327 # go back to just this axis's tick labels
#
# File ~/Documents/GitHub/.venv/lib/python3.11/site-packages/matplotlib/axis.py:1270, in Axis._update_ticks(self)
#    1268     tick.set_label1(label)
#    1269     tick.set_label2(label)
# -> 1270 minor_locs = self.get_minorticklocs()
#    1271 minor_labels = self.minor.formatter.format_ticks(minor_locs)
#    1272 minor_ticks = self.get_minor_ticks(len(minor_locs))
#
# File ~/Documents/GitHub/.venv/lib/python3.11/site-packages/matplotlib/axis.py:1491, in Axis.get_minorticklocs(self)
#    1489 minor_locs = np.asarray(self.minor.locator())
#    1490 if self.remove_overlapping_locs:
# -> 1491     major_locs = self.major.locator()
#    1492     transform = self._scale.get_transform()
#    1493     tr_minor_locs = transform.transform(minor_locs)
#
# File ~/Documents/GitHub/.venv/lib/python3.11/site-packages/matplotlib/ticker.py:2136, in MaxNLocator.__call__(self)
#    2134 def __call__(self):
#    2135     vmin, vmax = self.axis.get_view_interval()
# -> 2136     return self.tick_values(vmin, vmax)
#
# File ~/Documents/GitHub/.venv/lib/python3.11/site-packages/matplotlib/ticker.py:2144, in MaxNLocator.tick_values(self, vmin, vmax)
#    2141     vmin = -vmax
#    2142 vmin, vmax = mtransforms.nonsingular(
#    2143     vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2144 locs = self._raw_ticks(vmin, vmax)
#    2146 prune = self._prune
#    2147 if prune == 'lower':
#
# File ~/Documents/GitHub/.venv/lib/python3.11/site-packages/matplotlib/ticker.py:2083, in MaxNLocator._raw_ticks(self, vmin, vmax)
#    2081 if self._nbins == 'auto':
#    2082     if self.axis is not None:
# -> 2083         nbins = np.clip(self.axis.get_tick_space(),
#    2084                         max(1, self._min_n_ticks - 1), 9)
#    2085     else:
#    2086         nbins = 9
#
# File ~/Documents/GitHub/.venv/lib/python3.11/site-packages/matplotlib/axis.py:2476, in XAxis.get_tick_space(self)
#    2474 def get_tick_space(self):
#    2475     ends = mtransforms.Bbox.unit().transformed(
# -> 2476         self.axes.transAxes - self.figure.dpi_scale_trans)
#    2477     length = ends.width * 72
#    2478     # There is a heuristic here that the aspect ratio of tick text
#    2479     # is no more than 3:1
#
# File ~/Documents/GitHub/.venv/lib/python3.11/site-packages/matplotlib/transforms.py:1454, in Transform.__sub__(self, other)
#    1452     return NotImplemented
#    1453 for remainder, sub_tree in self._iter_break_from_left_to_right():
# -> 1454     if sub_tree == other:
#    1455         return remainder
#    1456 for remainder, sub_tree in other._iter_break_from_left_to_right():
#
# File ~/Documents/GitHub/.venv/lib/python3.11/site-packages/matplotlib/transforms.py:1780, in AffineBase.__eq__(self, other)
#    1776 def __array__(self, *args, **kwargs):
#    1777     # optimises the access of the transform matrix vs. the superclass
#    1778     return self.get_matrix()
# -> 1780 def __eq__(self, other):
#    1781     if getattr(other, "is_affine", False) and hasattr(other, "get_matrix"):
#    1782         return np.all(self.get_matrix() == other.get_matrix())
#
# KeyboardInterrupt:
